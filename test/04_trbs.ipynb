# %% [markdown]
# ### TRBs
#
# Tick run bars

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de visualización
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

print("✓ Imports completados")
# Out:
# ✓ Imports completados

# %%
from pathlib import Path
import sys

cwd = Path().resolve()
for p in [cwd] + list(cwd.parents):
    if (p / "utils").is_dir():
        sys.path.insert(0, str(p))
        break

from utils.download_data_binance import DowloadDataBinance as dt 
from utils.runs_bars import RunBars as rb
from utils.info_bars import InfoBars as ib
from utils.bars_visualizer import BarsVisualizer as bv

# %%
data_path = '../data/raw'
run_bars = rb(data_path)
info_bars = ib(data_path)
download_data = dt(data_path)
bars_visualizer = bv()

# %%
df = download_data.download_trades_binance(
    symbol='BTCUSDT',
    hours=120,  
    max_trades=300000
)

download_data.show_info(df)
# Out:
# Descargando trades de BTCUSDT...
# Trades: 12,000 | Iter: 12

# %%
trb_bars = run_bars.get_trbs(df)

# %%
tib_bars = info_bars.get_tibs(df)
dib_bars = info_bars.get_dibs(df)
vib_bars = info_bars.get_vibs(df)

# %%
print("len run bars: ", len(trb_bars))
print("len info bars: ", len(tib_bars), len(dib_bars), len(vib_bars))
# Out:
# len run bars:  107
# len info bars:  53 38 38

# %%
bars_visualizer.plot_bars(df, trb_bars)

# %%
bars_visualizer.plot_bars(df, tib_bars)

# %%
bars_visualizer.candle_bars(tib_bars, bar_type='TIB')

# %%
bars_visualizer.candle_bars(trb_bars)
